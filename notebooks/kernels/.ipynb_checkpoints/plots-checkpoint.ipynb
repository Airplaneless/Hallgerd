# %%
import numpy as np
import pylab as plt

# %%
data0 = np.load('k0.npz')
data1 = np.load('k1.npz')
data2 = np.load('k2.npz')
data6 = np.load('k6.npz')

# %%
list(data1.keys())
# Out:
# ['time', 'size', 'score']

# %%
plt.plot(data0['size'], data0['time'], label='k0')
plt.plot(data1['size'], data1['time'], label='k1')
plt.plot(data1['size'], data2['time'], label='k2')
plt.plot(data1['size'], data6['time'], label='k3')
plt.legend()
plt.show()
